# %% [markdown]
# <a href="https://colab.research.google.com/github/Achraf8EL/Analyse-des-Donn-es-M1/blob/main/TD1_Ex2_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ##Importation and description of the dataset

# %% [markdown]
# Question I-1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path_2='/content/drive/MyDrive/Colab Notebooks/titanic.csv'

# %%
df=pd.read_csv(path_2)
# df=pd.read_csv('titanic.csv')

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Question I-2

# %% [markdown]
# Hint : https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.info.html

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# Question I-3

# %% [markdown]
# Hint : https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html

# %%
newcolumns=['Survived','Age','SibSp','Fare']

# %% [markdown]
# What are the quartiles representing?
# ![quartiles.jpg](data:image/jpeg;base64,...)

# %%
df[newcolumns].describe()
# Out:
#          Survived         Age       SibSp        Fare
# count  891.000000  714.000000  891.000000  891.000000
# mean     0.383838   29.699118    0.523008   32.204208
# std      0.486592   14.526497    1.102743   49.693429
# min      0.000000    0.420000    0.000000    0.000000
# 25%      0.000000   20.125000    0.000000    7.910400
# 50%      0.000000   28.000000    0.000000   14.454200
# 75%      1.000000   38.000000    1.000000   31.000000
# max      1.000000   80.000000    8.000000  512.329200

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# Question I-4

# %% [markdown]
# Hint : https://pandas.pydata.org/docs/reference/api/pandas.isnull.html

# %%
missing_values=df.isnull().mean()*100

# Sort by descending order of missing values
missing_values_sorted = missing_values.sort_values(ascending=False)

print(missing_values_sorted)
# Out:
# Cabin          77.104377
# Age            19.865320
# Embarked        0.224467
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# dtype: float64

# %% [markdown]
# ##Basic graphic analysis

# %% [markdown]
# Question II-1

# %% [markdown]
# Hint: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html

# %%
labels=['PassengerId','Ticket','Name','Cabin']

# %%
df_clean=df.drop(columns=labels)
df_clean
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %% [markdown]
# Question II-2

# %% [markdown]
# Hint : https://datatofish.com/select-rows-pandas-dataframe/

# %%
df_men=df.loc[df['Sex'] == 'male']
df_women=df.loc[df['Sex'] == 'female']

# %% [markdown]
# Question II-3

# %% [markdown]
# Hint : https://seaborn.pydata.org/generated/seaborn.kdeplot.html

# %% [markdown]
# or https://seaborn.pydata.org/generated/seaborn.displot.html#seaborn.displot

# %% [markdown]
# If survived = 1 means that the passenger survived, how can you interpret the graphs below?

# %%
sns.kdeplot(data=df_men, x="Age", hue="Survived", multiple="stack")
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.kdeplot(data=df_women, x="Age", hue="Survived", multiple="stack")
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# Question II-3

# %% [markdown]
# Hint : https://seaborn.pydata.org/generated/seaborn.histplot.html or https://seaborn.pydata.org/generated/seaborn.barplot.html

# %% [markdown]
# What is the error bar representing? Check the parameter "errorbar" in the documentation: https://seaborn.pydata.org/generated/seaborn.barplot.html

# %%
sns.barplot(data=df, x="Embarked",  y="Survived", hue="Embarked")
# Out:
# <Axes: xlabel='Embarked', ylabel='Survived'>

# %% [markdown]
# *How can you interpret this graph? If someone embarked on port S and another person embarked on port C, who is more likely to survive? Considering this naive statistics analysis.*

# %% [markdown]
# Question II-4

# %%
sns.barplot(data=df, x="Pclass",  y="Survived", hue="Pclass")
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %% [markdown]
# *Again, how can you interpret this? Someone from the 2nd class had more chances of survival than someone from the first class?*
